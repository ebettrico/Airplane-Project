# %%
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm

# Google API Key
from config import gkey

# base url
base_url = "https://api.yelp.com/v3/businesses/matches"

# set up api_key dictionary
headers = {
        'Authorization': 'Bearer %s' % gkey,
    }

# set up a parameters dictionary
def s_params(lat_loc,long_loc,target_type,name):
    params = {
    "latitude": lat_loc,
    "longitude": long_loc,
    "categories": target_type,
    "Name": name
}
    return params
def s_query(base_url,headers,params):
    response = requests.request('GET', base_url, headers=headers, params=params).json()
    return response

# %%
types_df = pd.read_csv("../Resources/airport_info.csv")
types_df.head(40)
# Out:
#     Zirport ID                                        Name   \
# 0            1                               Goroka Airport
# 1            2                               Madang Airport
# 2            3                 Mount Hagen Kagamuga Airport
# 3            4                               Nadzab Airport
# 4            5  Port Moresby Jacksons International Airport
# 5            6                  Wewak International Airport
# 6            7                           Narsarsuaq Airport
# 7            8                      Godthaab / Nuuk Airport
# 8            9                        Kangerlussuaq Airport
# 9           10                               Thule Air Base
# 10          11                             Akureyri Airport
# 11          12                         EgilsstaÌ¡ir Airport
# 12          13                       HornafjÌ¦rÌ¡ur Airport
# 13          14                            HÌ¼savÌ?k Airport
# 14          15                        ÌsafjÌ¦rÌ¡ur Airport
# ...
